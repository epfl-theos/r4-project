# %%
# %aiida
from aiida import orm, load_profile
import matplotlib.pyplot as plt
from aiida.orm import QueryBuilder
from collections import Counter
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns
import ase
from math import pi
import numpy as np
from ase.atoms import Atoms
import asap3
from ase.calculators import calculator
from ase.calculators.calculator import Calculator, kpts2ndarray
from ase import Atoms
from operator import itemgetter 
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing 
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

# %%
#dataset load 
skip=100  #usually complete it is 79855
load_profile()
qb = QueryBuilder()
qb.append(orm.StructureData)
qb.count()
qb_red=qb.all()[::skip] #reduced dataset

# %%
# some useful functions
def removeElements(lst): 
    counted = Counter(lst) 
    return [el for el in lst if counted[el] >= len(lst)/1000] 

def point_group(structure):
    global pg
    if sg==1: #spacegroup
        pg='1' #pointgroup
        o=1   #number of operations
    elif sg==2:
        pg='1_'
        o=2
    elif 3<=sg<=5:
        pg='2'
        o=2
    elif 6<=sg<=9:
        pg='m'
        o=2
    elif 10<=sg<=15:
        pg='2/m'
        o=4
    elif 16<=sg<=24:
        pg='222'
        o=4
    elif 25<=sg<=46:
        pg='mm2'
        o=4
    elif 47<=sg<=74:
        pg='mmm'
        o=8
    elif 75<=sg<=80:
        pg='4'
        o=4
    elif 81<=sg<=82:
        pg='4_'
        o=4
    elif 83<=sg<=88:
        pg='4/m'
        o=8
    elif 89<=sg<=98:
        pg='422'
        o=8
    elif 99<=sg<=110:
        pg='4mm'
        o=8
    elif 111<=sg<=122:
        pg='4_2m'
        o=8
    elif 123<=sg<=142:
        pg='4/mmm'
        o=16
    elif 143<=sg<=146:
        pg='3'
        o=3
    elif 147<=sg<=148:
        pg='m3_'
        o=6
    elif 149<=sg<=155:
        pg='32'
        o=6
    elif 156<=sg<=161:
        pg='3m'
        o=6
    elif 162<=sg<=167:
        pg='3_m'
        o=12
    elif 168<=sg<=173:
        pg='6'
        o=6
    elif sg==174:
        pg='6_'
        o=6
    elif 175<=sg<=176:
        pg='6/m'
        o=12
    elif 177<=sg<=182:
        pg='622'
        o=12
    elif 183<=sg<=186:
        pg='6mm'
        o=12
    elif 187<=sg<=190:
        pg='6_m2'
        o=12
    elif 191<=sg<=194:
        pg='6/mmm'
        o=24
    elif 195<=sg<=199:
        pg='23'
        o=12
    elif 200<=sg<=206:
        pg='m_3'
        o=24
    elif 207<=sg<=214:
        pg='432'
        o=24
    elif 215<=sg<=220:
        pg='4_3m'
        o=24
    elif 221<=sg<=230:
        pg='m3_m'
        o=48
    
    return (pg,o)

def magic_four(lista):
    idx=[l for l in range(len(lista)) if lista[l] %4==0]
    return idx

# %%
n_atoms=[]

H=[]
He=[]
Li=[]
C=[]
N=[]
O= []
Na=[]
Al=[]
K=[]
Pt=[]
Au=[]

H_norm=[]
He_norm=[]
Li_norm=[]
C_norm=[]
N_norm=[]

yes_or_no=[]

general_metal=0
general_even=0
metal=0
even=0
number_structures_with_multiple_of_4=0
point_group_list=[]
for [structure_data] in qb_red:
    if 'spacegroup_number' in structure_data.extras:
        sg=structure_data.extras['spacegroup_number']


    #     print(type(structure_data), type([structure_data]), [structure_data]['data'])
        natom = len(structure_data.get_site_kindnames())
        atoms=structure_data.get_ase()
        number_electrons=sum(atoms.numbers)
        if number_electrons%2!=0:
            general_metal+=1
            if natom %4==0:
                metal+=1
        if number_electrons%2==0:
            general_even+=1
            if natom %4==0:
                even+=1
        if natom %4==0:
            number_structures_with_multiple_of_4+=1
            yes_or_no. append(1)
        else:
            yes_or_no.append(0)


        sp_group=point_group(sg)
        point_group_list.append(pg)

        n_atoms.append(natom)
        hyd=str(structure_data.get_site_kindnames()).count('H')
        H.append(hyd)
        H_norm.append(hyd/natom)
        hel=str(structure_data.get_site_kindnames()).count('He')
        He.append(hel)
        He_norm.append(hel/natom)
        li=str(structure_data.get_site_kindnames()).count('Li')
        Li.append(li)
        Li_norm.append(li/natom)
        carb=str(structure_data.get_site_kindnames()).count('C')
        C.append(carb)
        C_norm.append(carb/natom)
        nit=str(structure_data.get_site_kindnames()).count('N')
        N.append(nit)
        N_norm.append(nit/natom)
        o=str(structure_data.get_site_kindnames()).count('O')
        O.append(o)
        na=str(structure_data.get_site_kindnames()).count('Na')
        Na.append(na)
        al=str(structure_data.get_site_kindnames()).count('Al')
        Al.append(al)
        pot=str(structure_data.get_site_kindnames()).count('K')
        K.append(pot)
        pt=str(structure_data.get_site_kindnames()).count('Pt')
        Pt.append(pt)
        au=str(structure_data.get_site_kindnames()).count('Au')
        Au.append(au)

# %%
elem=[H, He, Li, C,N, O, Na, Al, K, Pt, Au]
c=['r','b', 'g', 'orange', 'magenta' ,'purple','deepskyblue','pink','black','grey','coral']
l=['H', 'He', 'Li', 'C', 'N', 'O', 'Na', 'Al', 'K', 'Pt', 'Au']
indexes=magic_four(n_atoms)
plt.figure(figsize=(15, 10))
for i in range(len(elem)):
    bbin=np.bincount(elem[i])
    magic=list(itemgetter(*indexes)(elem[i]))
    magic_bin = np.bincount(magic)
    div=[int(b) / int(m) for b,m in zip(magic_bin+1, bbin+1)]
    binss=range(len(div))   
    plt.plot(binss, div, color=c[i], label=l[i])
plt.xlim(-1, 100)
plt.legend()
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlabel('Abundance of specific element in unit cell', size=15)
plt.ylabel('Ratio of abundance occurrence in "magic" structures over whole dataset', size=15)
for i in range(0,500,4):
    plt.axvline(x=i, linestyle='--', c='grey', lw=0.5)
# plt.savefig("elements abundance rep1.png", bbox_inches='tight', dpi=400)
plt.show()
plt.close()
                            
n_atoms_magic = list(itemgetter(*indexes)(n_atoms))

data= {'number of atoms': n_atoms,
        'number of H': H,
#          'number of He': He,
        'number of Li': Li,
        'number of C': C, 
        'number of N': N, 
        'number of O': O,
        'number of Na': Na,
         'number of Al': Al,
         'number of K': K,
        'number of Pt': Pt, 
        'number of Au': Au 
        }

data_magic= {'number of atoms': n_atoms_magic,
        'number of H': H_magic,
#          'number of He': He_magic,
         'number of Li': Li_magic,
        'number of C': C_magic, 
        'number of N': N_magic, 
       'number of O': O_magic,
        'number of Na': Na_magic,
         'number of Al': Al_magic,
         'number of K': K_magic,
        'number of Pt': Pt_magic, 
        'number of Au': Au_magic 
        }

df = pd.DataFrame(data,columns=['number of atoms','number of H', 'number of Li', 'number of C','number of N',  'number of O',  'number of Na',  'number of Al',  'number of K',  'number of Pt',  'number of Au'])
df_magic=pd.DataFrame(data_magic, columns=['number of atoms','number of H','number of Li', 'number of C','number of N',  'number of O',  'number of Na',  'number of Al',  'number of K',  'number of Pt',  'number of Au'])

relation_pearson=df_magic.corr()/df.corr()
fig, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(relation_pearson, annot=True)
ax.tick_params(labelsize=13, direction='out')
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.title('"magic"/whole dataset correlation', size=25)
plt.savefig("CM_divided_pearson.png", bbox_inches='tight', dpi=400)
plt.show()

# %%
#PLOTS

# n_atoms_norm=[i/sum(n_atoms) for i in n_atoms]   
# H_norm=[i/sum(H) for i in H]
# C_norm=[i/sum(C) for i in C]
# N_norm=[i/sum(N) for i in N]
divH = [int(b) / int(m) for b,m in zip(H, n_atoms)]
divHe = [int(b) / int(m) for b,m in zip(He, n_atoms)]
divLi = [int(b) / int(m) for b,m in zip(Li, n_atoms)]
divC = [int(b) / int(m) for b,m in zip(C, n_atoms)]
divN = [int(b) / int(m) for b,m in zip(N, n_atoms)]
#histograms per element
sns.set(style="white", palette="muted", color_codes=True)
f, ax = plt.subplots(figsize=(9, 8))
# plt.figure()
sns.despine(left=True)
sns.histplot(data=n_atoms, stat="probability", color='b', discrete=True, label='number of atoms')
sns.histplot(data=He, stat="probability",color='b' ,fill=False, lw=1., discrete=True, label='He')
sns.histplot(data=H, stat="probability",color='r' ,fill=False, lw=1., discrete=True, label='H')
sns.histplot(data=Li, stat="probability",color='g' ,fill=False, lw=1., discrete=True, label='Li')
sns.histplot(data=C, stat="probability", color='orange', fill=False, lw=1.2, discrete=True, label='C')
sns.histplot(data=N, stat="probability", color='magenta', fill=False, discrete=True, label='N')
ax.set_xlim(-1, 100)
ax.set_xlabel('Atom count')
plt.legend()
ax.set_ylim(0, 0.1)
# plt.savefig('hist_together_norm.png', bbox_inches='tight', dpi=400)
plt.show()
plt.close()


# sns.set(style="white", palette="muted", color_codes=True)
# f, ax = plt.subplots(figsize=(9, 8))
# # plt.figure()
# sns.despine(left=True)
# sns.histplot(data=n_atoms, stat="probability", color='b', discrete=True, label='number of atoms')
# ax.set_xlim(-1, 100)
# ax.set_xlabel('Atom count')
# plt.legend()
# plt.savefig('hist_natom.png', bbox_inches='tight', dpi=400)
# plt.show()
# plt.close()

# sns.set(style="white", palette="muted", color_codes=True)
# f, ax = plt.subplots(figsize=(9, 8))
# # plt.figure()
# sns.despine(left=True)
# sns.histplot(data=n_atoms, stat="probability", color='b', discrete=True, label='number of atoms')
# sns.histplot(data=He, stat="probability",color='b' ,fill=False, lw=1., discrete=True, label='He')
# sns.histplot(data=H, stat="probability",color='r' ,fill=False, lw=1., discrete=True, label='H')
# sns.histplot(data=Li, stat="probability",color='g' ,fill=False, lw=1., discrete=True, label='Li')
# sns.histplot(data=C, stat="probability", color='orange', fill=False, lw=1.2, discrete=True, label='C')
# sns.histplot(data=N, stat="probability", color='magenta', fill=False, discrete=True, label='N')
# ax.set_xlim(-1, 100)
# ax.set_ylim(0, 0.1)
# ax.set_xlabel('Atom count')
# plt.legend()
# # plt.savefig('hist_together_red.png', bbox_inches='tight', dpi=400)
# plt.show()
# plt.close()

# #point groups
# plt.figure(figsize=(9, 13))
# plt.scatter (n_atoms, point_group_list, s=15, alpha=0.5)
# for i in range(0,200,4):
#     plt.axvline(x=i, linestyle='--', c='grey', lw=0.5)
# plt.xlabel("atom count", size=20)
# plt.ylabel("Point group", size=20)
# plt.yticks(size=20)
# plt.xticks(size=20)
# plt.xlim(0,100)
# # plt.savefig("point_group.png", bbox_inches='tight', dpi=400)
# plt.show()
# plt.close()

# #pie chart for metals 
percentage_str_4=int(number_structures_with_multiple_of_4*100/len(qb_red))
explode = (0, 0.1) 
labels=['odd', 'even']
colors = ['#ff9999','#66b3ff']
general=[general_metal, general_even]
local=[metal, even]
plt.title('Whole dataset ('+str(len(qb_red))+' structures)')
plt.pie(general, shadow=True, explode=explode,colors=colors, labels=labels, autopct='%1.0f%%')
# plt.savefig("pie_metal?_general.png", bbox_inches='tight', dpi=400)
plt.show()
plt.close()
plt.title('Only 4 and mulpitples structures ('+str(percentage_str_4)+'% of total)')
plt.pie(local, shadow=True, explode=explode,colors=colors,labels=labels, radius=0.8,  autopct='%1.0f%%')
# plt.savefig("pie_metal?.png", bbox_inches='tight', dpi=400)
plt.show()

# %%
#element occurrence 

plt.figure(figsize=(9, 8))
plt.scatter (n_atoms, divH, s=75, alpha=1, c='r', label='H')
plt.scatter (n_atoms, divHe, s=70, alpha=0.7, c='blue', label='He')
plt.scatter (n_atoms, divN, s=33, alpha=0.8, c='g', label='Li')
plt.scatter (n_atoms, divC, s=27, alpha=1, c='orange', label='C')
plt.scatter (n_atoms, divN, s=15, alpha=1, c='magenta', label='N')

plt.legend()
plt.xlabel("Number of atoms in unit cell", size=20)
for i in range(0,200,4):
    plt.axvline(x=i, linestyle='--', c='grey', lw=0.5)
plt.ylim(0.05, 1.05)
plt.ylabel("element relative abundance", size=20)
plt.yticks(size=20)
plt.xticks(size=20)
plt.xlim(0,100)
plt.savefig("element rel occ.png", bbox_inches='tight', dpi=400)
plt.show()
plt.close()

# %%
print(len(n_atoms), n_atoms)
na_mod=n_atoms.copy()
for (i, item) in enumerate(n_atoms):
    if item %4!=0:
        na_mod[i] = 0
print (len(na_mod), na_mod)
# Out:
# 799 [4, 32, 24, 18, 48, 3, 80, 32, 56, 6, 120, 52, 16, 12, 14, 84, 14, 4, 8, 4, 112, 6, 19, 20, 44, 24, 8, 12, 148, 96, 2, 6, 72, 16, 4, 106, 38, 54, 96, 24, 8, 12, 12, 10, 4, 44, 46, 22, 38, 34, 12, 4, 256, 92, 28, 48, 12, 66, 10, 5, 6, 20, 10, 328, 16, 26, 6, 28, 7, 10, 11, 36, 72, 12, 136, 40, 168, 6, 14, 18, 44, 6, 108, 60, 4, 32, 18, 208, 6, 40, 4, 40, 9, 56, 38, 20, 44, 12, 21, 16, 34, 6, 12, 9, 22, 36, 54, 26, 5, 48, 26, 16, 20, 36, 66, 68, 41, 20, 28, 88, 56, 12, 8, 12, 15, 14, 36, 32, 40, 8, 174, 10, 50, 12, 24, 7, 6, 12, 180, 34, 5, 28, 16, 24, 12, 22, 32, 22, 45, 22, 148, 72, 14, 80, 18, 12, 3, 17, 4, 56, 438, 6, 72, 7, 24, 14, 8, 6, 18, 3, 17, 2, 12, 68, 12, 70, 80, 45, 8, 52, 64, 45, 6, 30, 3, 12, 28, 60, 116, 20, 11, 10, 42, 28, 100, 36, 256, 18, 9, 48, 18, 68, 3, 108, 36, 36, 42, 10, 28, 20, 12, 20, 84, 72, 74, 59, 2, 64, 10, 24, 22, 18, 24, 22, 21, 14, 10, 28, 9, 6, 2, 48, 3, 24, 8, 18, 24, 20, 28, 102, 28, 5, 36, 12, 16, 16, 72, 20, 140, 48, 122, 6, 104, 36, 20, 76, 4, 32, 10, 36, 276, 28, 36, 4, 37, 10, 56, 16, 248, 12, 30, 40, 116, 32, 8, 18, 18, 84, 4, 18, 26, 4, 18, 56, 60, 36, 16, 60, 96, 514, 32, 92, 21, 376, 40, 3, 20, 120, 16, 14, 15, 40, 28, 24, 160, 5, 4, 116, 88, 54, 5, 76, 6, 6, 40, 18, 36, 44, 56, 16, 80, 52, 32, 5, 60, 8, 28, 36, 32, 84, 56, 32, 384, 40, 8, 80, 18, 60, 56, 33, 84, 128, 18, 3, 25, 14, 36, 80, 18, 56, 8, 12, 68, 34, 11, 52, 20, 20, 48, 8, 36, 8, 88, 340, 92, 36, 88, 48, 52, 24, 80, 28, 48, 120, 4, 12, 12, 16, 104, 72, 28, 3, 80, 116, 22, 36, 34, 36, 16, 106, 52, 48, 56, 44, 18, 34, 4, 7, 4, 34, 52, 74, 15, 28, 5, 24, 36, 96, 6, 48, 104, 22, 23, 10, 28, 60, 18, 22, 12, 8, 14, 80, 56, 80, 9, 17, 198, 128, 14, 2, 4, 88, 42, 340, 84, 4, 30, 16, 56, 14, 6, 9, 12, 120, 44, 40, 108, 2, 172, 44, 36, 15, 56, 41, 9, 42, 32, 14, 6, 36, 32, 5, 38, 10, 80, 70, 10, 9, 14, 64, 17, 40, 9, 20, 104, 20, 8, 5, 30, 8, 40, 18, 16, 3, 64, 1, 8, 40, 12, 16, 6, 5, 20, 32, 8, 36, 36, 32, 16, 28, 8, 6, 13, 24, 18, 5, 6, 6, 12, 9, 5, 6, 32, 5, 6, 56, 10, 32, 32, 24, 44, 124, 28, 92, 10, 68, 29, 24, 68, 54, 20, 28, 375, 94, 24, 9, 96, 16, 24, 80, 56, 44, 52, 136, 36, 304, 34, 20, 24, 90, 32, 44, 11, 10, 6, 23, 52, 88, 408, 6, 44, 32, 9, 30, 37, 48, 32, 16, 26, 20, 86, 22, 82, 12, 18, 768, 72, 72, 106, 64, 2, 32, 40, 44, 8, 18, 6, 28, 58, 4, 22, 28, 192, 28, 12, 20, 96, 80, 8, 24, 32, 44, 62, 42, 16, 1, 120, 12, 64, 3, 267, 12, 8, 34, 10, 9, 14, 46, 36, 16, 38, 4, 20, 36, 40, 6, 17, 7, 6, 11, 32, 4, 96, 4, 492, 308, 80, 22, 18, 180, 288, 86, 88, 102, 30, 32, 160, 268, 20, 44, 14, 16, 3, 54, 12, 174, 52, 10, 20, 30, 56, 168, 16, 8, 10, 136, 64, 69, 164, 18, 18, 4, 6, 9, 36, 40, 15, 46, 20, 128, 28, 92, 12, 44, 24, 72, 34, 72, 56, 24, 40, 48, 288, 44, 34, 140, 68, 24, 60, 272, 24, 124, 34, 116, 44, 9, 12, 66, 44, 64, 12, 48, 8, 34, 426, 8, 40, 76, 18, 200, 16, 52, 120, 42, 104, 128, 16, 120, 22, 12, 30, 168, 120, 32, 10, 10, 12, 14, 30, 11, 38, 96, 848, 6, 40, 36, 4, 30, 32, 22, 19, 22, 58, 24, 6, 24, 32, 4, 26, 36, 6, 6, 16, 8, 7, 52, 6, 24, 23, 36, 24, 24, 6, 18, 18, 9, 33, 36, 16, 24, 24, 6, 22, 8, 5, 8, 34, 3, 48, 8, 2, 7, 9, 4, 40, 12, 36, 38, 8]
# 799 [4, 32, 24, 0, 48, 0, 80, 32, 56, 0, 120, 52, 16, 12, 0, 84, 0, 4, 8, 4, 112, 0, 0, 20, 44, 24, 8, 12, 148, 96, 0, 0, 72, 16, 4, 0, 0, 0, 96, 24, 8, 12, 12, 0, 4, 44, 0, 0, 0, 0, 12, 4, 256, 92, 28, 48, 12, 0, 0, 0, 0, 20, 0, 328, 16, 0, 0, 28, 0, 0, 0, 36, 72, 12, 136, 40, 168, 0, 0, 0, 44, 0, 108, 60, 4, 32, 0, 208, 0, 40, 4, 40, 0, 56, 0, 20, 44, 12, 0, 16, 0, 0, 12, 0, 0, 36, 0, 0, 0, 48, 0, 16, 20, 36, 0, 68, 0, 20, 28, 88, 56, 12, 8, 12, 0, 0, 36, 32, 40, 8, 0, 0, 0, 12, 24, 0, 0, 12, 180, 0, 0, 28, 16, 24, 12, 0, 32, 0, 0, 0, 148, 72, 0, 80, 0, 12, 0, 0, 4, 56, 0, 0, 72, 0, 24, 0, 8, 0, 0, 0, 0, 0, 12, 68, 12, 0, 80, 0, 8, 52, 64, 0, 0, 0, 0, 12, 28, 60, 116, 20, 0, 0, 0, 28, 100, 36, 256, 0, 0, 48, 0, 68, 0, 108, 36, 36, 0, 0, 28, 20, 12, 20, 84, 72, 0, 0, 0, 64, 0, 24, 0, 0, 24, 0, 0, 0, 0, 28, 0, 0, 0, 48, 0, 24, 8, 0, 24, 20, 28, 0, 28, 0, 36, 12, 16, 16, 72, 20, 140, 48, 0, 0, 104, 36, 20, 76, 4, 32, 0, 36, 276, 28, 36, 4, 0, 0, 56, 16, 248, 12, 0, 40, 116, 32, 8, 0, 0, 84, 4, 0, 0, 4, 0, 56, 60, 36, 16, 60, 96, 0, 32, 92, 0, 376, 40, 0, 20, 120, 16, 0, 0, 40, 28, 24, 160, 0, 4, 116, 88, 0, 0, 76, 0, 0, 40, 0, 36, 44, 56, 16, 80, 52, 32, 0, 60, 8, 28, 36, 32, 84, 56, 32, 384, 40, 8, 80, 0, 60, 56, 0, 84, 128, 0, 0, 0, 0, 36, 80, 0, 56, 8, 12, 68, 0, 0, 52, 20, 20, 48, 8, 36, 8, 88, 340, 92, 36, 88, 48, 52, 24, 80, 28, 48, 120, 4, 12, 12, 16, 104, 72, 28, 0, 80, 116, 0, 36, 0, 36, 16, 0, 52, 48, 56, 44, 0, 0, 4, 0, 4, 0, 52, 0, 0, 28, 0, 24, 36, 96, 0, 48, 104, 0, 0, 0, 28, 60, 0, 0, 12, 8, 0, 80, 56, 80, 0, 0, 0, 128, 0, 0, 4, 88, 0, 340, 84, 4, 0, 16, 56, 0, 0, 0, 12, 120, 44, 40, 108, 0, 172, 44, 36, 0, 56, 0, 0, 0, 32, 0, 0, 36, 32, 0, 0, 0, 80, 0, 0, 0, 0, 64, 0, 40, 0, 20, 104, 20, 8, 0, 0, 8, 40, 0, 16, 0, 64, 0, 8, 40, 12, 16, 0, 0, 20, 32, 8, 36, 36, 32, 16, 28, 8, 0, 0, 24, 0, 0, 0, 0, 12, 0, 0, 0, 32, 0, 0, 56, 0, 32, 32, 24, 44, 124, 28, 92, 0, 68, 0, 24, 68, 0, 20, 28, 0, 0, 24, 0, 96, 16, 24, 80, 56, 44, 52, 136, 36, 304, 0, 20, 24, 0, 32, 44, 0, 0, 0, 0, 52, 88, 408, 0, 44, 32, 0, 0, 0, 48, 32, 16, 0, 20, 0, 0, 0, 12, 0, 768, 72, 72, 0, 64, 0, 32, 40, 44, 8, 0, 0, 28, 0, 4, 0, 28, 192, 28, 12, 20, 96, 80, 8, 24, 32, 44, 0, 0, 16, 0, 120, 12, 64, 0, 0, 12, 8, 0, 0, 0, 0, 0, 36, 16, 0, 4, 20, 36, 40, 0, 0, 0, 0, 0, 32, 4, 96, 4, 492, 308, 80, 0, 0, 180, 288, 0, 88, 0, 0, 32, 160, 268, 20, 44, 0, 16, 0, 0, 12, 0, 52, 0, 20, 0, 56, 168, 16, 8, 0, 136, 64, 0, 164, 0, 0, 4, 0, 0, 36, 40, 0, 0, 20, 128, 28, 92, 12, 44, 24, 72, 0, 72, 56, 24, 40, 48, 288, 44, 0, 140, 68, 24, 60, 272, 24, 124, 0, 116, 44, 0, 12, 0, 44, 64, 12, 48, 8, 0, 0, 8, 40, 76, 0, 200, 16, 52, 120, 0, 104, 128, 16, 120, 0, 12, 0, 168, 120, 32, 0, 0, 12, 0, 0, 0, 0, 96, 848, 0, 40, 36, 4, 0, 32, 0, 0, 0, 0, 24, 0, 24, 32, 4, 0, 36, 0, 0, 16, 8, 0, 52, 0, 24, 0, 36, 24, 24, 0, 0, 0, 0, 0, 36, 16, 24, 24, 0, 0, 8, 0, 8, 0, 0, 48, 8, 0, 0, 0, 4, 40, 12, 36, 0, 8]

# %%
data= {'number of atoms': n_atoms,
       'n magic':na_mod, 
        'number of H': H,
#          'number of He': He,
        'number of Li': Li,
        'number of C': C, 
        'number of N': N, 
        'number of O': O,
        'number of Na': Na,
         'number of Al': Al,
         'number of K': K        
      }

df = pd.DataFrame(data,columns=['number of atoms','n magic', 'number of H', 'number of Li', 'number of C','number of N',  'number of O',  'number of Na',  'number of Al',  'number of K'])
fig, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(df.corr(), annot=True)
ax.tick_params(labelsize=13, direction='out')
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.title('Whole CM', size=25)
plt.savefig("CM.png", bbox_inches='tight', dpi=400)
plt.show()

titles=['number of atoms','n magic', 'number of H', 'number of Li', 'number of C','number of N',  'number of O',  'number of Na',  'number of Al',  'number of K']

scatter_matrix(df[titles], figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='number of atoms', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of atoms'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of atoms'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='n magic'>,
#         <AxesSubplot:xlabel='n magic', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of H', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of C', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of N', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of O', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='n magic'>,
#         <AxesSubplot:xlabel='number of K', ylabel='n magic'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of H'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of H'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of H'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of Li'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of Li'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of C'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of C'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of C'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of N'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of N'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of N'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of O'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of O'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of O'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of Na'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of Na'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of Al'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of Al'>],
#        [<AxesSubplot:xlabel='number of atoms', ylabel='number of K'>,
#         <AxesSubplot:xlabel='n magic', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of H', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of Li', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of C', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of N', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of O', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of Na', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of Al', ylabel='number of K'>,
#         <AxesSubplot:xlabel='number of K', ylabel='number of K'>]],
#       dtype=object)

# %%
#correlations matrix old 

encoder = LabelEncoder()

indexes=magic_four(n_atoms)

print('Percentage of structures with 4 and multiples atoms in unit cell is '+ str(len(indexes)*100/len(n_atoms)) +'%')

n_atoms_magic = list(itemgetter(*indexes)(n_atoms))

H_magic = list(itemgetter(*indexes)(divH)) 
He_magic = list(itemgetter(*indexes)(divHe)) 
Li_magic = list(itemgetter(*indexes)(divLi)) 
C_magic = list(itemgetter(*indexes)(divC))
N_magic = list(itemgetter(*indexes)(divN))
pg_magic=list(itemgetter(*indexes)(point_group_list))
yes_or_no_magic=list(itemgetter(*indexes)(yes_or_no))

# H_magic_norm = list(itemgetter(*indexes)(H_norm)) 
# C_magic_norm = list(itemgetter(*indexes)(C_norm))
# N_magic_norm = list(itemgetter(*indexes)(N_norm))

data = {'number of atoms': n_atoms,
        'number of H': divH, 
#         'number of He': divHe, 
        'number of Li': divLi, 
        'number of C': divC, 
        'number of N': divN
#         'point group':point_group_list
#         'yes or no':yes_or_no
        }

data_magic= {'number of atoms': n_atoms_magic,
        'number of H': H_magic,
#          'number of He': He_magic,
         'number of Li': Li_magic,
        'number of C': C_magic, 
        'number of N': N_magic 
#         'point group':pg_magic
        }

df = pd.DataFrame(data,columns=['number of atoms','number of H', 'number of Li', 'number of C', 'number of N'])
df_magic= pd.DataFrame(data_magic,columns=['number of atoms','number of H', 'number of Li', 'number of C', 'number of N'])
# df_magic_norm= pd.DataFrame(data_magic_norm,columns=['number of atoms','number of H','number of C', 'number of N', 'point group'])

#encoding point groups into numbers:
# df['point group']=encoder.fit_transform(df['point group'])
# df_magic['point group']=encoder.fit_transform(df_magic['point group'])
# # df_magic_norm['point group']=encoder.fit_transform(df_magic_norm['point group'])


fig, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(df.corr(), annot=True)
ax.tick_params(labelsize=13, direction='out')
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.title('Whole CM', size=25)
plt.savefig("CM.png", bbox_inches='tight', dpi=400)
plt.show()

fig, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(df_magic.corr(), annot=True)
ax.tick_params(labelsize=13, direction='out')
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.title('Magic CM', size=25)
plt.savefig("magicCM.png", bbox_inches='tight', dpi=400)
plt.show()


relation_pearson=df.corr()/df_magic.corr()
fig, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(relation_pearson, annot=True)
ax.tick_params(labelsize=13, direction='out')
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.title('Whole/"magic" dataset correlation', size=25)
plt.savefig("CM_divided_pearson.png", bbox_inches='tight', dpi=400)
plt.show()

titles=['number of atoms','number of H','number of C', 'number of N', 'point group']
# scatter_matrix(df_magic_norm[titles], figsize=(15, 15))
# Out:
# Percentage of structures with 4 and multiples atoms in unit cell is 61.82728410513141%
